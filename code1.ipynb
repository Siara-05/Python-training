# %% [markdown]
# ### Write a program to accept two string from user and append it

# %%
def append():
    str1 = input("Enter your first string name: ")
    str2 = input("Enter your second string name: ")
    str3 = str1 + str2 

    print(str3)

append()
# Out:
# premsubha
