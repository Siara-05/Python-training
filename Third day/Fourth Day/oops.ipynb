# %% [markdown]
# # OOP's

# %% [markdown]
# ## 1. Inheritence

# %%
class father():
    def king(self):
        print(" I am king of my family")

# %%
class Sun(father):
    def ni(self):
        print(" I am sun")
