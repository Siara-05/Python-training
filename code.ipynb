# %% [markdown]
# # Data types in python

# %%
a = 10      ## Integer
name = "subha"                   # String
b = 10.1                         # Float

list1 = [10,20,30,'hi']              # hetrogeneous list
ab = True
print(list1)
print(ab)
variables = [a,name,b,ab,list1]
# Out:
# [10, 20, 30, 'hi']
# True

# %%
for var in variables:
    print(var,type(var))
# Out:
# 10 <class 'int'>
# subha <class 'str'>
# [10, 20, 30, 'hi'] <class 'list'>
# True <class 'bool'>

# %%
number = float(input("Put your input here : "))
print(type(number))
# Out:
# <class 'float'>

# %%
print(type(list1))
# Out:
# <class 'list'>

# %%
print(id(list1))
# Out:
# 2339919866816

# %% [markdown]
# ### WAP to accept two numbers from user

# %%
Num1 = int(input("Enter your first number : "))
Num2 = int(input("Enter your second number : "))

print(Num1 , Num2)
sum1=Num1 + Num2
print("addition of two numbers:", sum1)
# Out:
# 25 25
# addition of two numbers: 50

# %%
### Functions in python

# %% [markdown]
# ### Function in Python
